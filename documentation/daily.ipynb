# %% [markdown]
# **Project:** Catan AI
# **Date:** 2026-03-13
# **Start time:** 16:00
# **End time:** 17:00
# **Session goal:** Setup project. Run a game
#
# Cloned catanatron (https://github.com/bcollazo/catanatron) as submodule. Added .gitignore.
# Created venv: <code>py -m venv</code>. Then activate with: <code>.\venv\Scripts\Activate.ps1</code> if windows or <code>./venv/Scripts/activate</code> if linux. Installed developer dependencies: <code>pip install -e ./catanatron[web,gym,dev]</code>.
# Ran a small simulation to check working dependencies.
